# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
sns.set_style('white')
# %matplotlib inline

# %%
df = pd.read_csv('small_countries_are_beautiful.csv')
df.head()
# Out:
#    indicator                              population  \
# 0     source                     Heritage Foundation
# 1        URL  https://www.heritage.org/index/explore
# 2      notes                                     NaN
# 3  data year                                    2018
# 4    Albania                               2,900,000
#
#                                      GDP   \
# 0                     Heritage Foundation
# 1  https://www.heritage.org/index/explore
# 2                         (billions, PPP)
# 3                                    2018
# 4                                   34.20
#
#                                    GDP .1  \
# 0                     Heritage Foundation
# 1  https://www.heritage.org/index/explore
# 2                        per capita (PPP)
# 3                                   2,018
# 4                                  11,840
#
#                              GDP per km2   \
# 0                     Heritage Foundation
# ...

# %%
df.drop([0, 1, 2, 3], inplace = True)
df.head()
# Out:
#   indicator population   GDP   GDP .1 GDP per km2  land area (sq km)  \
# 4   Albania  2,900,000  34.20  11,840    1,248,266            27,398
# 5   Armenia  3,000,000  25.80   8,621      914,796            28,203
# 6   Bahamas    400,000   9.00  24,555      899,101            10,010
# 7   Bahrain  1,300,000  66.90  50,704   88,026,316               760
# 8  Barbados    300,000   4.80  17,100   11,162,791               430
#
#   population density  total foreign-born\npopulation   \
# 4                 105                          57,616
# 5                 103                         191,199
# 6                  39                          59,306
# 7                1936                         704,137
# 8                 664                          34,475
#
#   % foreign-born population population living abroad (diaspora)  \
# 4                      3.10                             1122910
# 5                     10.60                              937299
# ...

# %%
df.rename(columns = {'indicator': 'Countries', 'population': 'Population (2018)', 
                    'GDP': 'GDP (2018)', 'GDP .1': 'GDP .1 (2018)', 
                     'GDP per km2': 'GDP(sq km)', 
                     'land area (sq km)': 'Land Area(sq km) (2018)',
                    'population density': 'Population Density(sq km) (2017)', 
                    'total foreign-born population': 'Total foreign-born population (2015)', 
                    '% foreign-born population': 'Percentage of foreign-born population (2015)', 
                    'population living abroad (diaspora)': 'Diaspora (2015)', 
                    'population living abroad': 'Population living abroad (2015)', 
                    'happy planet index': 'Happy Planet Index (2016)', 
                    'world happiness report score': 'World Happiness Report Score (2017)', 
                    'human development index': 'HDI (2017)', 
                    'health expenditure': 'Health expenditure (2015)', 
                    'education expenditure': 'Education expenditure'}, inplace = True)
df.head().reset_index(drop = True)
# Out:
#   Countries Population (2018)   GDP  GDP .1 (2018) GDP per km2   \
# 0   Albania         2,900,000  34.20        11,840    1,248,266
# 1   Armenia         3,000,000  25.80         8,621      914,796
# 2   Bahamas           400,000   9.00        24,555      899,101
# 3   Bahrain         1,300,000  66.90        50,704   88,026,316
# 4  Barbados           300,000   4.80        17,100   11,162,791
#
#   Land Area(sq km) (2018) population density  total foreign-born\npopulation   \
# 0                  27,398                 105                          57,616
# 1                  28,203                 103                         191,199
# 2                  10,010                  39                          59,306
# 3                     760                1936                         704,137
# 4                     430                 664                          34,475
#
#   Percentage of foreign-born population (2015) Diaspora (2015)  \
# ...
